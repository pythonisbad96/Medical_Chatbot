# %% [markdown]
# # 아산병원 상세페이지 1278건 크롤링
# `amc_disease_links.csv`에 담긴 링크를 기반으로
# 각 질환의 **질환명 / 증상 / 진료과** 정보를 수집하여 `amc_disease_1278pages.csv`로 저장합니다.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time

# %%
# 링크 CSV 파일 불러오기
df_links = pd.read_csv("amc_disease_links.csv")
links = df_links["상세페이지링크"].tolist()
print(f"총 링크 수: {len(links)}")
# Out:
# 총 링크 수: 1278

# %%
def get_symptom_text(soup):
    # 1차 시도: 본문 내부 dt -> dd
    dts = soup.select("div.contDescription dt")
    for dt in dts:
        if "증상" in dt.get_text(strip=True):
            dd = dt.find_next_sibling("dd")
            if dd:
                ps = dd.find_all("p")
                if ps:
                    return " ".join(
                        p.get_text(strip=True).replace("\n", " ") for p in ps
                    )
                else:
                    return dd.get_text(strip=True).replace("\n", " ")

    # 2차 시도: 썸네일 옆 요약 정보
    try:
        dd = soup.select_one(
            "#content > div.healthinfoWrap.clearfix > div.regionReviewLeft > div.otherRegionBox > ul > li > div.contBox > dl > dd:nth-child(2)"
        )
        if dd:
            return " ".join(
                a.get_text(strip=True).replace("\n", " ") for a in dd.find_all("a")
            )
    except:
        pass

    return ""

# %%
def get_symptom_text(soup):
    # 1차 시도: 본문 내부 dt -> dd
    dts = soup.select('div.contDescription dt')
    for dt in dts:
        if "증상" in dt.get_text(strip=True):
            dd = dt.find_next_sibling("dd")
            if dd:
                ps = dd.find_all("p")
                if ps:
                    return " ".join(p.get_text(strip=True) for p in ps)
                else:
                    return dd.get_text(strip=True)

    # 2차 시도: 썸네일 옆 요약 정보
    try:
        dd = soup.select_one(
            "#content > div.healthinfoWrap.clearfix > div.regionReviewLeft > div.otherRegionBox > ul > li > div.contBox > dl > dd:nth-child(2)"
        )
        if dd:
            return ", ".join(a.get_text(strip=True) for a in dd.find_all("a"))
    except:
        pass

    return ''

# %%
# def get_symptom_text(soup):
#     try:
#         # 정확한 위치의 dd:nth-child(6) 가져오기
#         dd = soup.select_one(
#             "#content > div.healthinfoWrap.clearfix > div.regionReviewLeft > div.contDescription > dl > dd:nth-child(6)"
#         )
#         if dd:
#             # 우선 <div><p>...</p></div> 구조 탐색
#             div = dd.find("div")
#             if div:
#                 ps = div.find_all("p")
#                 if ps:
#                     return "\n".join(p.get_text(strip=True) for p in ps)
#                 else:
#                     return div.get_text(strip=True)

#             # <p> 태그가 dd 안에 직접 있는 경우
#             ps = dd.find_all("p")
#             if ps:
#                 return "\n".join(p.get_text(strip=True) for p in ps)

#             # <p>도 <div>도 없는 경우: dd 내부 전체 텍스트
#             return dd.get_text(strip=True)

#     except Exception as e:
#         print(f"[증상 추출 오류] {e}")

#     return ""

# %%
def get_dept_text(soup):
    dts = soup.select("div.otherRegionBox dt")
    for dt in dts:
        if "진료과" in dt.get_text(strip=True):
            dd = dt.find_next_sibling("dd")
            if dd:
                return ", ".join(a.get_text(strip=True) for a in dd.find_all("a"))
    return ""

# %%
def get_section_text(soup, title):
    try:
        dts = soup.select("div.contDescription dt")
        for dt in dts:
            if title in dt.get_text(strip=True):
                dd = dt.find_next_sibling("dd")
                if dd:
                    # 1. dd > div > p 구조
                    div = dd.find("div")
                    if div:
                        ps = div.find_all("p")
                        if ps:
                            return " ".join(
                                p.get_text(strip=True).replace("\n", " ") for p in ps
                            )
                        return div.get_text(strip=True).replace("\n", " ")

                    # 2. dd > p 구조
                    ps = dd.find_all("p")
                    if ps:
                        return " ".join(
                            p.get_text(strip=True).replace("\n", " ") for p in ps
                        )

                    # 3. fallback: dd 텍스트 전체
                    return dd.get_text(strip=True).replace("\n", " ")
    except Exception as e:
        print(f"[{title} 추출 오류] {e}")

    return ""

# %%
results = []
headers = {"User-Agent": "Mozilla/5.0"}

# 셀렉터
sel_title = "#content > div.healthinfoWrap.clearfix > div.regionReviewLeft > div.otherRegionBox > ul > li > div.contBox > strong"


for i, url in enumerate(links):
    try:
        res = requests.get(url, headers=headers, timeout=10)
        soup = BeautifulSoup(res.text, "html.parser")

        # 병명
        title_tag = soup.select_one(sel_title)
        title = title_tag.get_text(strip=True) if title_tag else ""

        # 증상
        symptom = get_symptom_text(soup)

        # 진료과
        dept = get_dept_text(soup)

        definition = get_section_text(soup, "정의")
        cause = get_section_text(soup, "원인")
        diagnosis = get_section_text(soup, "진단")
        treatment = get_section_text(soup, "치료")

        results.append(
            {
                "병명": title,
                "정의": definition,
                "원인": cause,
                "증상": symptom,
                "진단": diagnosis,
                "치료": treatment,
                "진료과": dept,
            }
        )

        print(f"[{i+1}/{len(links)}] 완료: {title}")
        time.sleep(1)

    except Exception as e:
        print(f"[에러] {url} - {e}")
        continue
# Out:
# [1/1278] 완료: 18번 염색체 단완결실 증후군(18p monosomy)
# [2/1278] 완료: 18번 염색체 장완결실 증후군 (18q monosomy)
# [3/1278] 완료: 22번 염색체 장완 미세결실 증후군(CATCH22)
# [4/1278] 완료: 4번 염색체 단완결실 증후군(Wolf-Hirschhorn syndrome)
# [5/1278] 완료: ARC 증후군(Arthrogryposis, Renal dysfunction, Cholestasis, ARC syndrome)
# [6/1278] 완료: Haw River 증후군(Dentatorubro-Pallidoluysian atrophy(DRPLA))
# [7/1278] 완료: MERRF(Myoclonic Epilepsy with Ragged Red Fiber) 증후군(Myoclonic epilepsy associated with ragged red fibers(MERRF))
# [8/1278] 완료: OTC 결핍증 (Ornithine-transcarbamylase deficiency)
# [9/1278] 완료: PSA 상승(Elevated PSA)
# [10/1278] 완료: RS바이러스 감염증(RS virus infection)
# [11/1278] 완료: Rh 부적합 임신(Rh Incompatibility pregnancy)
# [12/1278] 완료: VDT 증후군(Visual Display Terminal Syndrome)
# [13/1278] 완료: WPW 증후군(Wolff-Parkinson-White syndrome)
# [14/1278] 완료: XXX 증후군(XXX syndrome)
# [15/1278] 완료: XYY 증후군(XYY syndrome)
# [16/1278] 완료: 가부키 증후군(Kabuki Syndrome)
# [17/1278] 완료: 가성근시(Pseudomyopia)
# [18/1278] 완료: 가스 괴저(Gas gangrene)
# [19/1278] 완료: 가습기 살균제 연관 폐질환(Humidifier disinfectant-associated lung injury)
# [20/1278] 완료: 가와사키병(Kawasaki Disease)
# [21/1278] 완료: 가족성 적혈구잠식성 림프조직구증(Hemophagocytic lymphohistiocytosis, Familial)
# [22/1278] 완료: 가진통(False labor)
# [23/1278] 완료: 각기병(Beriberi)
# [24/1278] 완료: 각막 궤양(Corneal ulcer)
# [25/1278] 완료: 각막 부종(Corneal Edema)
# [26/1278] 완료: 각막 혼탁과 흉터(Corneal opacity and scar)
# [27/1278] 완료: 각막염(Keratitis)
# [28/1278] 완료: 간 전이(Liver Metastasis)
# [29/1278] 완료: 간 혈관종(Hepatic hemangioma)
# [30/1278] 완료: 간경화(Liver cirrhosis)
# [31/1278] 완료: 간내 담석(IHD stone)
# [32/1278] 완료: 간농양(Liver abscess)
# [33/1278] 완료: 간디스토마(Clonorchisis sinensis)
# [34/1278] 완료: 간문부 담관암(Klatskin's tumor)
# [35/1278] 완료: 간성 뇌증(Hepatic encephalopathy)
# [36/1278] 완료: 간세포암(Hepatocellular carcinoma)
# [37/1278] 완료: 간신 증후군(Hepatorenal syndrome)
# [38/1278] 완료: 간염(Hepatitis)
# [39/1278] 완료: 간의 양성 신생물(Benign neoplasm of the liver)
# [40/1278] 완료: 간이식 후 상태(Liver Transplantation status)
# [41/1278] 완료: 간질성 방광염(Interstitial Cystitis)
# [42/1278] 완료: 간찰성 홍반(Erythema intertrigo)
# [43/1278] 완료: 갈락토오스혈증(Galactosemia)
# [44/1278] 완료: 갈색세포종(Pheochromocytoma)
# [45/1278] 완료: 감각신경성 난청(Sensorineural hearing loss)
# [46/1278] 완료: 감돈포경(Paraphimosis)
# [47/1278] 완료: 감염성 근육염(Infective myositis)
# [48/1278] 완료: 감염성 단핵구증(Infectious mononucleosis)
# [49/1278] 완료: 감염성 홍반(Erythema infectiosum)
# [50/1278] 완료: 갑상선 결절(Thyroid nodule)
# [51/1278] 완료: 갑상선 미분화암(Undifferentiated thyroid cancer)
# [52/1278] 완료: 갑상선 수질암(Medullary thyroid cancer)
# [53/1278] 완료: 갑상선 여포암(Follicular thyroid cancer)
# [54/1278] 완료: 갑상선 유두암(Papillary Carcinoma of Thyroid )
# [55/1278] 완료: 갑상선기능저하증(Hypothyroidism)
# [56/1278] 완료: 갑상선기능항진증(Hyperthyroidism)
# [57/1278] 완료: 갑상선암(Thyroid cancer)
# [58/1278] 완료: 갑상선염(Thyroiditis)
# [59/1278] 완료: 갑상선중독증(Thyrotoxicosis)
# [60/1278] 완료: 갑상설관 낭종(Thyroglossal duct cyst)
# [61/1278] 완료: 강박 장애(Obsessive-Compulsive Disorder)
# [62/1278] 완료: 강직성 척추염(Ankylosing spondylitis)
# [63/1278] 완료: 객혈(Hemoptysis)
# [64/1278] 완료: 거대 유방(Macromastia, Gigantomastia, large breast, hypermas)
# [65/1278] 완료: 거대세포 바이러스 질환(Cytomegaloviral diseases)
# [66/1278] 완료: 거대적혈모구빈혈(Megaloblastic anemia)
# [67/1278] 완료: 거북목 증후군(Turtle neck syndrome)
# [68/1278] 완료: 거스트만 증후군(Gerstmann Syndrome)
# [69/1278] 완료: 건 손상(Tendon injury)
# [70/1278] 완료: 건강염려증(Hypochondriasis)
# [71/1278] 완료: 건선(Psoriasis)
# [72/1278] 완료: 건초염(Tenosynovitis)
# [73/1278] 완료: 게실 질환(Diverticular disease)
# [74/1278] 완료: 결막염(Conjunctivitis)
# [75/1278] 완료: 결절성 경화증 (Tuberous sclerosis)
# [76/1278] 완료: 결절성 다발동맥염(Polyarteritis nodosa)
# [77/1278] 완료: 결절종(Ganglion)
# [78/1278] 완료: 결핵(Tuberculosis)
# [79/1278] 완료: 결핵성 골수염(Tuberculous osteomyelitis)
# [80/1278] 완료: 결핵성 복막염(Tuberculous peritonitis)
# [81/1278] 완료: 결핵성 수막염(Tuberculous meningitis)
# [82/1278] 완료: 결핵성 임파선염(Tuberculous lymphadenitis)
# [83/1278] 완료: 경계성 인격장애(Borderline personality disorder)
# [84/1278] 완료: 경골과 비골 골절(Fracture of tibia & fibula)
# [85/1278] 완료: 경동맥 협착증(Carotid artery stenosis)
# [86/1278] 완료: 경미한 인지장애(Mild cognitive impairment)
# [87/1278] 완료: 경부 림프절염(Cervical lymphadenitis)
# [88/1278] 완료: 경추 추간판 탈출증(Cervical HIVD)
# [89/1278] 완료: 경화성 담관염(Sclerosing cholangitis)
# [90/1278] 완료: 계류 유산(Missed abortion)
# [91/1278] 완료: 고관절 이형성증(DDH (developmental dysplasia of the hip))
# [92/1278] 완료: 고나트륨혈증(Hypernatremia)
# [93/1278] 완료: 고마그네슘혈증(Hypermagnesemia)
# [94/1278] 완료: 고막염(Myringitis)
# [95/1278] 완료: 고산병(Mountain sickness)
# [96/1278] 완료: 고셔병(Gaucher disease)
# [97/1278] 완료: 고칼륨혈증(Hyperkalemia)
# [98/1278] 완료: 고칼슘혈증(Hypercalcemia)
# [99/1278] 완료: 고콜레스테롤혈증(Pure hypercholesterolemia)
# [100/1278] 완료: 고혈압(Essential (primary) hypertension)
# [101/1278] 완료: 고환 여성화 증후군(Testicular feminization syndrome)
# [102/1278] 완료: 고환 종양(Tumors of testis)
# [103/1278] 완료: 고환염(Orchitis)
# [104/1278] 완료: 고환의 염전(Torsion of testis)
# [105/1278] 완료: 골감소증(Osteopenia)
# [106/1278] 완료: 골관절염(Osteoarthritis)
# [107/1278] 완료: 골괴사(Osteonecrosis)
# [108/1278] 완료: 골다공증(Osteoporosis)
# [109/1278] 완료: 골덴하 증후군(Goldenhar syndrome)
# [110/1278] 완료: 골반 염증성 질환(Pelvic inflammatory disease)
# [111/1278] 완료: 골수염(Osteomyelitis)
# [112/1278] 완료: 골수증식종양(Myeloproliferative neoplasm)
# [113/1278] 완료: 골수형성이상증후군(Myelodysplastic syndromes)
# [114/1278] 완료: 골육종(Osteosarcoma)
# [115/1278] 완료: 골절 후 부정 유합, 불유합(Malunion & nonunion of fracture)
# [116/1278] 완료: 골형성부전증(Osteogenesis imperfecta)
# [117/1278] 완료: 곰팡이 감염(Fungal infection)
# [118/1278] 완료: 공기가슴증(기흉)(Pneumothorax)
# [119/1278] 완료: 공황 장애(Panic disorder)
# [120/1278] 완료: 과다월경(Hypermenorrhea)
# [121/1278] 완료: 과립막 세포종(Granulosa cell tumor)
# [122/1278] 완료: 과민성 방광(Overactive Bladder)
# [123/1278] 완료: 과숙아, 만기 후 출산아(Post-term infant)
# [124/1278] 완료: 과오종(Hamartoma)
# [125/1278] 완료: 과호흡 증후군(Hyperventilation syndrome)
# [126/1278] 완료: 관절염(Arthritis)
# [127/1278] 완료: 관절와순 파열(Labral tear)
# [128/1278] 완료: 광견병(Rabies)
# [129/1278] 완료: 광선 각화증(Actinic Keratosis)
# [130/1278] 완료: 광우병(Bovine spongiform encephalopathy)
# [131/1278] 완료: 광장공포증(Agoraphobia)
# [132/1278] 완료: 괴혈병(scurvy)
# [133/1278] 완료: 교모세포종(Glioblastoma)
# [134/1278] 완료: 구강암(Oral Cancer)
# [135/1278] 완료: 구개열(Cleft palate)
# [136/1278] 완료: 구루병(Rickets)
# [137/1278] 완료: 구순열(Cleft lip)
# [138/1278] 완료: 구순염(Cheilitis)
# [139/1278] 완료: 구순포진(Herpes labialis)
# [140/1278] 완료: 구토(Vomiting)
# [141/1278] 완료: 구획 증후군(Compartment syndrome)
# [142/1278] 완료: 국소 다한증(Localized hyperhidrosis)
# [143/1278] 완료: 군발성 두통 증후군(Cluster headache syndrome)
# [144/1278] 완료: 궤양성 대장염(Ulcerative colitis)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 41
#      28     results.append(
#      29         {
#      30             "병명": title,
#    (...)
#      37         }
#      38     )
#      40     print(f"[{i+1}/{len(links)}] 완료: {title}")
# ---> 41     time.sleep(1)
#      43 except Exception as e:
#      44     print(f"[에러] {url} - {e}")
#
# KeyboardInterrupt:

# %%
# # CSV 저장
df = pd.DataFrame(results)
df.to_csv("amc_disease_more.csv", index=False, encoding="utf-8-sig")
print("✅ CSV 저장 완료")
